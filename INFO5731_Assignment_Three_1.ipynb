# %% [markdown]
# <a href="https://colab.research.google.com/github/kamalrajugambli/KamalRaju_INFO5731_SPRING2022/blob/main/INFO5731_Assignment_Three_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment.

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as all the 100 reviews (abstracts, or tweets).

# %%
import csv, collections, nltk, pandas as pd, numpy as np, textblob
from gensim.models import Word2Vec

# Run this command to download all data related to nltk : python3 -m nltk.downloader all
nltk.download('brown')
nltk.download('punkt')
########## Variables #############
INPUT_FILE_PATH = '/content/reviewdataset.csv'

# Reading the file and storing in an array
def read_lines_from_csv(filepath):
    lines = []
    with open(filepath) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        # Skip the header
        next(csv_reader, None)
        for row in csv_reader:
            lines.append(row[1].lower().replace('.', ' ').replace('-', ' ').replace(',', ' '))
    return lines
    
lines = read_lines_from_csv(INPUT_FILE_PATH)    


def get_ngrams_for_sentences(sentences, n):
    ngrams = []
    for sentence in sentences:
        # find ngrams
        ngram_words = list(nltk.ngrams(sentence.split(), n))
        ngram_words = [' '.join(ngram) for ngram in ngram_words]
        ngrams.extend(ngram_words)
    return ngrams

########## Part-1 : Frequency of Trigrams ##########
# Reference : https://rpubs.com/TuPham/ngrams
trigrams = get_ngrams_for_sentences(lines, 3)
trigrams_frequencies = dict(collections.Counter(trigrams).most_common())
print('Trigram frequencies: ')
print(trigrams_frequencies)

########## Part-2 : N-gram probability ##########
# Reference : https://towardsdatascience.com/understanding-word-n-grams-and-n-gram-probability-in-natural-language-processing-9d9eef0fa058
unigrams = get_ngrams_for_sentences(lines, 1)
bigrams = get_ngrams_for_sentences(lines, 2)

unigram_frequencies = dict(collections.Counter(unigrams).most_common())
bigram_frequencies = dict(collections.Counter(bigrams).most_common())

# Calculating bigrams probability
probabilites = {}
for bigram in bigrams:
    w2, w1 = bigram.split(' ')
    probabilites[bigram] = bigram_frequencies[bigram] / unigram_frequencies[w2]
print('Bigram probabilities: ')
print(probabilites)

########## Part-3 : Noun phrases & its relative probability ##########
lines = lines[:100]
all_noun_phrases = []
review_noun_frequency_map = {}
for line in lines:
    noun_phrases = textblob.TextBlob(line).noun_phrases
    noun_phrases_frequencies = dict(collections.Counter(noun_phrases))
    review_noun_frequency_map[line] = noun_phrases_frequencies
    all_noun_phrases.extend(noun_phrases)
all_noun_phrases_frequencies = dict(collections.Counter(all_noun_phrases))

# All unique noun phrases
unique_noun_phrases = list(set(all_noun_phrases))

relative_probability_table = pd.DataFrame([], columns=unique_noun_phrases, index=lines)

for line in lines:
    noun_phrases_frequencies = review_noun_frequency_map[line]
    for noun_phrase in noun_phrases_frequencies.keys():
        relative_probability = noun_phrases_frequencies[noun_phrase] / all_noun_phrases_frequencies[noun_phrase]
        relative_probability_table.loc[line, noun_phrase] = relative_probability
relative_probability_table = relative_probability_table.fillna(0)
display(relative_probability_table)
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#                                                     high expectations  \
# i am not a big fan of the many  many marvel fil...                0.0
# shaun (simu liu) and katy (awkwafina) are slack...                0.0
# it was an okay movie  simu liu is the son of th...                0.0
# shaun (simu liu) and katy (awkwafina) are parki...                0.0
# i was not expecting that  i had visions of a fi...                0.0
# ...                                                               ...
# i had low expectations for this movie  first of...                0.0
# let's keep aside all these serious conversation...                0.0
# destin daniel cretton's 'shang chi and the lege...                0.0
# one of the best origin mcu films  good story  g...                0.0
# i really had fun with this new marvel movie  i ...                0.0
#
#                                                     great fight  \
# i am not a big fan of the many  many marvel fil...          0.0
# shaun (simu liu) and katy (awkwafina) are slack...          0.0
# it was an okay movie  simu liu is the son of th...          0.0
# shaun (simu liu) and katy (awkwafina) are parki...          0.0
# i was not expecting that  i had visions of a fi...          0.0
# ...                                                         ...
# i had low expectations for this movie  first of...          0.0
# let's keep aside all these serious conversation...          0.0
# destin daniel cretton's 'shang chi and the lege...          0.0
# one of the best origin mcu films  good story  g...          0.0
# i really had fun with this new marvel movie  i ...          0.0
#
#                                                     displays imagery  \
# i am not a big fan of the many  many marvel fil...               0.0
# shaun (simu liu) and katy (awkwafina) are slack...               0.0
# it was an okay movie  simu liu is the son of th...               0.0
# shaun (simu liu) and katy (awkwafina) are parki...               0.0
# i was not expecting that  i had visions of a fi...               0.0
# ...                                                              ...
# i had low expectations for this movie  first of...               0.0
# let's keep aside all these serious conversation...               0.0
# destin daniel cretton's 'shang chi and the lege...               0.0
# one of the best origin mcu films  good story  g...               0.0
# i really had fun with this new marvel movie  i ...               0.0
#
#                                                     jon jon tsai chin  \
# i am not a big fan of the many  many marvel fil...                0.0
# shaun (simu liu) and katy (awkwafina) are slack...                0.0
# it was an okay movie  simu liu is the son of th...                0.0
# shaun (simu liu) and katy (awkwafina) are parki...                0.0
# i was not expecting that  i had visions of a fi...                0.0
# ...                                                               ...
# i had low expectations for this movie  first of...                0.0
# let's keep aside all these serious conversation...                0.0
# destin daniel cretton's 'shang chi and the lege...                0.0
# one of the best origin mcu films  good story  g...                0.0
# i really had fun with this new marvel movie  i ...                0.0
#
#                                                     control shang chi  \
# i am not a big fan of the many  many marvel fil...                0.0
# shaun (simu liu) and katy (awkwafina) are slack...                0.0
# it was an okay movie  simu liu is the son of th...                0.0
# shaun (simu liu) and katy (awkwafina) are parki...                0.0
# i was not expecting that  i had visions of a fi...                0.0
# ...                                                               ...
# i had low expectations for this movie  first of...                0.0
# let's keep aside all these serious conversation...                0.0
# destin daniel cretton's 'shang chi and the lege...                0.0
# one of the best origin mcu films  good story  g...                0.0
# i really had fun with this new marvel movie  i ...                0.0
#
#                                                     villain father  \
# i am not a big fan of the many  many marvel fil...             0.0
# shaun (simu liu) and katy (awkwafina) are slack...             0.0
# it was an okay movie  simu liu is the son of th...             0.0
# shaun (simu liu) and katy (awkwafina) are parki...             0.0
# i was not expecting that  i had visions of a fi...             0.0
# ...                                                            ...
# i had low expectations for this movie  first of...             0.0
# let's keep aside all these serious conversation...             0.0
# destin daniel cretton's 'shang chi and the lege...             0.0
# one of the best origin mcu films  good story  g...             0.0
# i really had fun with this new marvel movie  i ...             0.0
#
#                                                     studio 's insistence  \
# i am not a big fan of the many  many marvel fil...                   0.0
# shaun (simu liu) and katy (awkwafina) are slack...                   0.0
# it was an okay movie  simu liu is the son of th...                   0.0
# shaun (simu liu) and katy (awkwafina) are parki...                   0.0
# i was not expecting that  i had visions of a fi...                   0.0
# ...                                                                  ...
# i had low expectations for this movie  first of...                   0.0
# let's keep aside all these serious conversation...                   0.0
# destin daniel cretton's 'shang chi and the lege...                   0.0
# one of the best origin mcu films  good story  g...                   0.0
# i really had fun with this new marvel movie  i ...                   0.0
#
#                                                     black widow  \
# i am not a big fan of the many  many marvel fil...          0.0
# shaun (simu liu) and katy (awkwafina) are slack...          0.0
# it was an okay movie  simu liu is the son of th...          0.0
# shaun (simu liu) and katy (awkwafina) are parki...          0.0
# i was not expecting that  i had visions of a fi...          0.0
# ...                                                         ...
# i had low expectations for this movie  first of...          0.0
# let's keep aside all these serious conversation...          0.0
# destin daniel cretton's 'shang chi and the lege...          0.0
# one of the best origin mcu films  good story  g...          0.0
# i really had fun with this new marvel movie  i ...          0.0
#
#                                                     likable hero shaun/shang chi awkwafina  \
# i am not a big fan of the many  many marvel fil...                                     0.0
# shaun (simu liu) and katy (awkwafina) are slack...                                     0.0
# it was an okay movie  simu liu is the son of th...                                     0.0
# shaun (simu liu) and katy (awkwafina) are parki...                                     0.0
# i was not expecting that  i had visions of a fi...                                     0.0
# ...                                                                                    ...
# i had low expectations for this movie  first of...                                     0.0
# let's keep aside all these serious conversation...                                     0.0
# destin daniel cretton's 'shang chi and the lege...                                     0.0
# one of the best origin mcu films  good story  g...                                     0.0
# i really had fun with this new marvel movie  i ...                                     0.0
#
#                                                     stunt work  ...  \
# i am not a big fan of the many  many marvel fil...         0.0  ...
# shaun (simu liu) and katy (awkwafina) are slack...         0.0  ...
# it was an okay movie  simu liu is the son of th...         0.0  ...
# shaun (simu liu) and katy (awkwafina) are parki...         0.0  ...
# i was not expecting that  i had visions of a fi...         0.0  ...
# ...                                                        ...  ...
# i had low expectations for this movie  first of...         0.0  ...
# let's keep aside all these serious conversation...         0.0  ...
# destin daniel cretton's 'shang chi and the lege...         0.0  ...
# one of the best origin mcu films  good story  g...         0.0  ...
# i really had fun with this new marvel movie  i ...         0.0  ...
#
#                                                     central performances  \
# i am not a big fan of the many  many marvel fil...                   0.0
# shaun (simu liu) and katy (awkwafina) are slack...                   0.0
# it was an okay movie  simu liu is the son of th...                   0.0
# shaun (simu liu) and katy (awkwafina) are parki...                   0.0
# i was not expecting that  i had visions of a fi...                   0.0
# ...                                                                  ...
# i had low expectations for this movie  first of...                   0.0
# let's keep aside all these serious conversation...                   0.0
# destin daniel cretton's 'shang chi and the lege...                   0.0
# one of the best origin mcu films  good story  g...                   0.0
# i really had fun with this new marvel movie  i ...                   0.0
#
#                                                     inane i  final hand  \
# i am not a big fan of the many  many marvel fil...      0.0         0.0
# shaun (simu liu) and katy (awkwafina) are slack...      0.0         0.0
# it was an okay movie  simu liu is the son of th...      0.0         0.0
# shaun (simu liu) and katy (awkwafina) are parki...      0.0         0.0
# i was not expecting that  i had visions of a fi...      0.0         0.0
# ...                                                     ...         ...
# i had low expectations for this movie  first of...      0.0         0.0
# let's keep aside all these serious conversation...      0.0         0.0
# destin daniel cretton's 'shang chi and the lege...      0.0         0.0
# one of the best origin mcu films  good story  g...      0.0         0.0
# i really had fun with this new marvel movie  i ...      0.0         0.0
#
#                                                     father tony leung  \
# i am not a big fan of the many  many marvel fil...                0.0
# shaun (simu liu) and katy (awkwafina) are slack...                0.0
# it was an okay movie  simu liu is the son of th...                0.0
# shaun (simu liu) and katy (awkwafina) are parki...                0.0
# i was not expecting that  i had visions of a fi...                0.0
# ...                                                               ...
# i had low expectations for this movie  first of...                0.0
# let's keep aside all these serious conversation...                0.0
# destin daniel cretton's 'shang chi and the lege...                0.0
# one of the best origin mcu films  good story  g...                0.0
# i really had fun with this new marvel movie  i ...                0.0
#
#                                                     film 's credibility  \
# i am not a big fan of the many  many marvel fil...                  0.0
# shaun (simu liu) and katy (awkwafina) are slack...                  0.0
# it was an okay movie  simu liu is the son of th...                  0.0
# shaun (simu liu) and katy (awkwafina) are parki...                  0.0
# i was not expecting that  i had visions of a fi...                  0.0
# ...                                                                 ...
# i had low expectations for this movie  first of...                  0.0
# let's keep aside all these serious conversation...                  0.0
# destin daniel cretton's 'shang chi and the lege...                  0.0
# one of the best origin mcu films  good story  g...                  0.0
# i really had fun with this new marvel movie  i ...                  0.0
#
#                                                     weakest aspects  \
# i am not a big fan of the many  many marvel fil...              0.0
# shaun (simu liu) and katy (awkwafina) are slack...              0.0
# it was an okay movie  simu liu is the son of th...              0.0
# shaun (simu liu) and katy (awkwafina) are parki...              0.0
# i was not expecting that  i had visions of a fi...              0.0
# ...                                                             ...
# i had low expectations for this movie  first of...              0.0
# let's keep aside all these serious conversation...              0.0
# destin daniel cretton's 'shang chi and the lege...              0.0
# one of the best origin mcu films  good story  g...              0.0
# i really had fun with this new marvel movie  i ...              0.0
#
#                                                     super hero  \
# i am not a big fan of the many  many marvel fil...         0.0
# shaun (simu liu) and katy (awkwafina) are slack...         0.0
# it was an okay movie  simu liu is the son of th...         0.0
# shaun (simu liu) and katy (awkwafina) are parki...         0.0
# i was not expecting that  i had visions of a fi...         0.0
# ...                                                        ...
# i had low expectations for this movie  first of...         0.0
# let's keep aside all these serious conversation...         0.0
# destin daniel cretton's 'shang chi and the lege...         0.0
# one of the best origin mcu films  good story  g...         0.0
# i really had fun with this new marvel movie  i ...         0.0
#
#                                                     benedict wong i  \
# i am not a big fan of the many  many marvel fil...              0.0
# shaun (simu liu) and katy (awkwafina) are slack...              0.0
# it was an okay movie  simu liu is the son of th...              0.0
# shaun (simu liu) and katy (awkwafina) are parki...              0.0
# i was not expecting that  i had visions of a fi...              0.0
# ...                                                             ...
# i had low expectations for this movie  first of...              0.0
# let's keep aside all these serious conversation...              0.0
# destin daniel cretton's 'shang chi and the lege...              0.0
# one of the best origin mcu films  good story  g...              0.0
# i really had fun with this new marvel movie  i ...              0.0
#
#                                                     mother wenwu  \
# i am not a big fan of the many  many marvel fil...           0.0
# shaun (simu liu) and katy (awkwafina) are slack...           0.0
# it was an okay movie  simu liu is the son of th...           0.0
# shaun (simu liu) and katy (awkwafina) are parki...           0.0
# i was not expecting that  i had visions of a fi...           0.0
# ...                                                          ...
# i had low expectations for this movie  first of...           0.0
# let's keep aside all these serious conversation...           0.0
# destin daniel cretton's 'shang chi and the lege...           0.0
# one of the best origin mcu films  good story  g...           0.0
# i really had fun with this new marvel movie  i ...           0.0
#
#                                                     gentle benign character
# i am not a big fan of the many  many marvel fil...                      0.0
# shaun (simu liu) and katy (awkwafina) are slack...                      0.0
# it was an okay movie  simu liu is the son of th...                      0.0
# shaun (simu liu) and katy (awkwafina) are parki...                      0.0
# i was not expecting that  i had visions of a fi...                      0.0
# ...                                                                     ...
# i had low expectations for this movie  first of...                      0.0
# let's keep aside all these serious conversation...                      0.0
# destin daniel cretton's 'shang chi and the lege...                      0.0
# one of the best origin mcu films  good story  g...                      0.0
# i really had fun with this new marvel movie  i ...                      0.0
#
# [100 rows x 1920 columns]

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (20 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
# Write your code here

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

########## Part-1 : document term matrix ##########
# Read data from files
lines = read_lines_from_csv(INPUT_FILE_PATH)    

# Find document - terms weights using TfidfVectorizer of sklearn for dataset.
count_vect = TfidfVectorizer(analyzer='word', ngram_range=(1, 1))
count_matrix = count_vect.fit_transform(lines).toarray()
documents_terms_weights = pd.DataFrame(index=lines, data=count_matrix, columns=count_vect.get_feature_names_out())
display(documents_terms_weights)

########## Part-2 : document term matrix ##########
# Reference : https://studymachinelearning.com/cosine-similarity-text-similarity-metric/
queries = ['best movie i have ever seen']

# Find document - terms weights using TfidfVectorizer of sklearn for query.
query_count_vect = TfidfVectorizer(analyzer='word', ngram_range=(1, 1))
query_count_matrix = query_count_vect.fit_transform(queries).toarray()
query_tokens = query_count_vect.get_feature_names_out()
query_documents_terms_weights = pd.DataFrame(index=queries, data=query_count_matrix, columns=query_tokens)

similarity_matrix = cosine_similarity(documents_terms_weights.loc[:, query_tokens], query_count_matrix)
similarity_matrix_df = pd.DataFrame(index=lines, columns=['cosine similarity'], data=similarity_matrix)
similarity_matrix_df = similarity_matrix_df.sort_values(by='cosine similarity', ascending=False)
display(similarity_matrix_df)
# Out:
#                                                     000  007   01   05  \
# i am not a big fan of the many  many marvel fil...  0.0  0.0  0.0  0.0
# shaun (simu liu) and katy (awkwafina) are slack...  0.0  0.0  0.0  0.0
# it was an okay movie  simu liu is the son of th...  0.0  0.0  0.0  0.0
# shaun (simu liu) and katy (awkwafina) are parki...  0.0  0.0  0.0  0.0
# i was not expecting that  i had visions of a fi...  0.0  0.0  0.0  0.0
# ...                                                 ...  ...  ...  ...
# my review  \nshang chi and the legend of the te...  0.0  0.0  0.0  0.0
# the best solo marvel movie if not the best movi...  0.0  0.0  0.0  0.0
# there are no words to describe the look of this...  0.0  0.0  0.0  0.0
# i am not interested in popcorn movies at all  h...  0.0  0.0  0.0  0.0
# the dialogue is terrible no really big characte...  0.0  0.0  0.0  0.0
#
#                                                           10  100  1000  \
# i am not a big fan of the many  many marvel fil...  0.000000  0.0   0.0
# shaun (simu liu) and katy (awkwafina) are slack...  0.000000  0.0   0.0
# it was an okay movie  simu liu is the son of th...  0.000000  0.0   0.0
# shaun (simu liu) and katy (awkwafina) are parki...  0.000000  0.0   0.0
# i was not expecting that  i had visions of a fi...  0.081721  0.0   0.0
# ...                                                      ...  ...   ...
# my review  \nshang chi and the legend of the te...  0.062754  0.0   0.0
# the best solo marvel movie if not the best movi...  0.000000  0.0   0.0
# there are no words to describe the look of this...  0.000000  0.0   0.0
# i am not interested in popcorn movies at all  h...  0.000000  0.0   0.0
# the dialogue is terrible no really big characte...  0.000000  0.0   0.0
#
#                                                     100shang  100this  \
# i am not a big fan of the many  many marvel fil...       0.0      0.0
# shaun (simu liu) and katy (awkwafina) are slack...       0.0      0.0
# it was an okay movie  simu liu is the son of th...       0.0      0.0
# shaun (simu liu) and katy (awkwafina) are parki...       0.0      0.0
# i was not expecting that  i had visions of a fi...       0.0      0.0
# ...                                                      ...      ...
# my review  \nshang chi and the legend of the te...       0.0      0.0
# the best solo marvel movie if not the best movi...       0.0      0.0
# there are no words to describe the look of this...       0.0      0.0
# i am not interested in popcorn movies at all  h...       0.0      0.0
# the dialogue is terrible no really big characte...       0.0      0.0
#
#                                                     100what  ...  zelda  zero  \
# i am not a big fan of the many  many marvel fil...      0.0  ...    0.0   0.0
# shaun (simu liu) and katy (awkwafina) are slack...      0.0  ...    0.0   0.0
# it was an okay movie  simu liu is the son of th...      0.0  ...    0.0   0.0
# shaun (simu liu) and katy (awkwafina) are parki...      0.0  ...    0.0   0.0
# i was not expecting that  i had visions of a fi...      0.0  ...    0.0   0.0
# ...                                                     ...  ...    ...   ...
# my review  \nshang chi and the legend of the te...      0.0  ...    0.0   0.0
# the best solo marvel movie if not the best movi...      0.0  ...    0.0   0.0
# there are no words to describe the look of this...      0.0  ...    0.0   0.0
# i am not interested in popcorn movies at all  h...      0.0  ...    0.0   0.0
# the dialogue is terrible no really big characte...      0.0  ...    0.0   0.0
#
#                                                     zest     zhang  zheng  \
# i am not a big fan of the many  many marvel fil...   0.0  0.000000    0.0
# shaun (simu liu) and katy (awkwafina) are slack...   0.0  0.000000    0.0
# it was an okay movie  simu liu is the son of th...   0.0  0.060177    0.0
# shaun (simu liu) and katy (awkwafina) are parki...   0.0  0.085930    0.0
# i was not expecting that  i had visions of a fi...   0.0  0.000000    0.0
# ...                                                  ...       ...    ...
# my review  \nshang chi and the legend of the te...   0.0  0.000000    0.0
# the best solo marvel movie if not the best movi...   0.0  0.000000    0.0
# there are no words to describe the look of this...   0.0  0.000000    0.0
# i am not interested in popcorn movies at all  h...   0.0  0.000000    0.0
# the dialogue is terrible no really big characte...   0.0  0.000000    0.0
#
#                                                     zingers  zombie  zone  \
# i am not a big fan of the many  many marvel fil...      0.0     0.0   0.0
# shaun (simu liu) and katy (awkwafina) are slack...      0.0     0.0   0.0
# it was an okay movie  simu liu is the son of th...      0.0     0.0   0.0
# shaun (simu liu) and katy (awkwafina) are parki...      0.0     0.0   0.0
# i was not expecting that  i had visions of a fi...      0.0     0.0   0.0
# ...                                                     ...     ...   ...
# my review  \nshang chi and the legend of the te...      0.0     0.0   0.0
# the best solo marvel movie if not the best movi...      0.0     0.0   0.0
# there are no words to describe the look of this...      0.0     0.0   0.0
# i am not interested in popcorn movies at all  h...      0.0     0.0   0.0
# the dialogue is terrible no really big characte...      0.0     0.0   0.0
#
#                                                     zoomy  áll
# i am not a big fan of the many  many marvel fil...    0.0  0.0
# shaun (simu liu) and katy (awkwafina) are slack...    0.0  0.0
# it was an okay movie  simu liu is the son of th...    0.0  0.0
# shaun (simu liu) and katy (awkwafina) are parki...    0.0  0.0
# i was not expecting that  i had visions of a fi...    0.0  0.0
# ...                                                   ...  ...
# my review  \nshang chi and the legend of the te...    0.0  0.0
# the best solo marvel movie if not the best movi...    0.0  0.0
# there are no words to describe the look of this...    0.0  0.0
# i am not interested in popcorn movies at all  h...    0.0  0.0
# the dialogue is terrible no really big characte...    0.0  0.0
#
# [2394 rows x 11541 columns]
#                                                     cosine similarity
# didn't have high hope before going in because n...           0.981960
# another marvel comics movie  this one takes one...           0.981960
# overall  i really liked the film  but i don't t...           0.974556
# one of the best marvel movie i have ever seen  ...           0.953004
# the movie was one of the best movies that i hav...           0.953004
# ...                                                               ...
# shang chi is full of amazing action (like aweso...           0.000000
# this film brought good feeling about family and...           0.000000
# disappointed by the story but seems like the wh...           0.000000
# nonsense dumb time wasted lots of dumb jokes\nn...           0.000000
# the dialogue is terrible no really big characte...           0.000000
#
# [2394 rows x 1 columns]

# %% [markdown]
# # **Question 3: Create your own word embedding model**

# %% [markdown]
# (20 points). Use the data you collected for assignment two to build a word embedding model:
#
# (1) Train a 300-dimension word embedding (it can be word2vec, glove, ulmfit, bert, or others).
#
# (2) Visualize the word embedding model you created.
#
# Reference: https://machinelearningmastery.com/develop-word-embeddings-python-gensim/

# %%
# Write your code here
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import random
from nltk.corpus import stopwords
nltk.download('stopwords')
from gensim.models import Word2Vec


########## Part-1 : Training word2vec word embedding model ##########
# Read data from files
lines = read_lines_from_csv(INPUT_FILE_PATH)    
tokenised_lines = []
stop_words = set(stopwords.words('english'))
for line in lines:
    tokens = line.split()
    tokens = [token for token in tokens if not token.lower() in stop_words]
    tokenised_lines.append(tokens)
lines = tokenised_lines
model = Word2Vec(sentences = lines, size = 300, window = 3)


########## Part-2 : Visualising word embedding model ##########
# Reference: https://towardsdatascience.com/visualizing-word-embedding-with-pca-and-t-sne-961a692509f5

topn = 4
batch_size = 4
unique_words = list(model.wv.index2entity)
sampled_words = random.choices(unique_words, k=batch_size)

all_words = []
two_dimensional_data = []
for sample_word in sampled_words:
    similar_words = model.wv.most_similar(sample_word, topn=topn)
    similar_words = [word[0] for word in similar_words]
    word_vectors = np.array([model.wv[word] for word in similar_words])

    all_words.extend(similar_words)
    two_dimensional_data.extend(PCA(random_state=0).fit_transform(word_vectors)[:,:2])

x = [point[0] for point in two_dimensional_data]
y = [point[1] for point in two_dimensional_data]

plt.scatter(x, y)
plt.title('Scatter plot for similar words')

for i in range(len(all_words)):
    plt.annotate(all_words[i], (x[i], y[i]))
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # **Question 4: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each review (abstract or tweet) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
# The GitHub link of your final csv file


# Link: "https://github.com/kamalrajugambli/KamalRaju_INFO5731_SPRING2022/blob/main/dataanalysissentiments.csv"
